# %%
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install pyvirtualdisplay
# !pip install tf-agents[reverb]
# !pip install pyglet

import sys

if sys.platform == "linux" or sys.platform == "linux2": 
    # !sudo apt update &&  sudo apt-get install ffmpeg libsm6 libxext6  -y
    # !sudo apt-get install libpython3.6-dev
# Out:
# Hit:1 http://ppa.launchpad.net/xapienz/curl34/ubuntu focal InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:3 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:4 https://cli.github.com/packages stable InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:7 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable InRelease
# Hit:8 https://packages.microsoft.com/repos/microsoft-ubuntu-focal-prod focal InRelease
# Hit:9 https://packagecloud.io/github/git-lfs/ubuntu focal InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# freeglut3-dev is already the newest version (2.8.1-3).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# xvfb is already the newest version (2:1.20.13-1ubuntu1~20.04.3).
# 0 upgraded, 0 newly installed, 0 to remove and 9 not upgraded.
# Requirement already satisfied: imageio==2.4.0 in /opt/python/3.10.4/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: pillow in /opt/python/3.10.4/lib/python3.10/site-packages (from imageio==2.4.0) (9.2.0)
# Requirement already satisfied: numpy in /opt/python/3.10.4/lib/python3.10/site-packages (from imageio==2.4.0) (1.23.1)
# Requirement already satisfied: pyvirtualdisplay in /opt/python/3.10.4/lib/python3.10/site-packages (3.0)
# Requirement already satisfied: tf-agents[reverb] in /opt/python/3.10.4/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: protobuf>=3.11.3 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (3.19.4)
# Requirement already satisfied: pygame==2.1.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (1.23.1)
# Requirement already satisfied: six>=1.10.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (1.16.0)
# Requirement already satisfied: absl-py>=0.6.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (4.3.0)
# Requirement already satisfied: gin-config>=0.4.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (0.5.0)
# Requirement already satisfied: cloudpickle>=1.3 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (2.1.0)
# Requirement already satisfied: gym<=0.23.0,>=0.17.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (0.23.0)
# Requirement already satisfied: tensorflow-probability>=0.16.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (0.17.0)
# Requirement already satisfied: pillow in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (9.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (1.14.1)
# Requirement already satisfied: dm-reverb~=0.8.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (0.8.0)
# Requirement already satisfied: rlds in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (0.1.5)
# Requirement already satisfied: tensorflow~=2.9.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tf-agents[reverb]) (2.9.1)
# Requirement already satisfied: dm-tree in /opt/python/3.10.4/lib/python3.10/site-packages (from dm-reverb~=0.8.0->tf-agents[reverb]) (0.1.7)
# Requirement already satisfied: portpicker in /opt/python/3.10.4/lib/python3.10/site-packages (from dm-reverb~=0.8.0->tf-agents[reverb]) (1.5.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/python/3.10.4/lib/python3.10/site-packages (from gym<=0.23.0,>=0.17.0->tf-agents[reverb]) (0.0.8)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (1.1.2)
# Requirement already satisfied: packaging in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (21.3)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (14.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (0.26.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (1.1.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (1.12)
# Requirement already satisfied: setuptools in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (58.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (1.47.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (3.3.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow~=2.9.0->tf-agents[reverb]) (2.9.1)
# Requirement already satisfied: decorator in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorflow-probability>=0.16.0->tf-agents[reverb]) (5.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow~=2.9.0->tf-agents[reverb]) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (2.28.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (2.10.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/python/3.10.4/lib/python3.10/site-packages (from packaging->tensorflow~=2.9.0->tf-agents[reverb]) (3.0.9)
# Requirement already satisfied: psutil in /opt/python/3.10.4/lib/python3.10/site-packages (from portpicker->dm-reverb~=0.8.0->tf-agents[reverb]) (5.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/python/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/python/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/python/3.10.4/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/python/3.10.4/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/python/3.10.4/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-agents[reverb]) (3.2.0)
# Requirement already satisfied: pyglet in /opt/python/3.10.4/lib/python3.10/site-packages (1.5.26)
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://packages.microsoft.com/repos/microsoft-ubuntu-focal-prod focal InRelease
# Hit:3 http://ppa.launchpad.net/xapienz/curl34/ubuntu focal InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:5 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:8 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:9 https://packagecloud.io/github/git-lfs/ubuntu focal InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 9 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.3-1).
# libxext6 is already the newest version (2:1.3.4-0ubuntu1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 9 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libpython3.6-dev
# E: Couldn't find any package by glob 'libpython3.6-dev'
# E: Couldn't find any package by regex 'libpython3.6-dev'

# %%
from __future__ import absolute_import, division, print_function

import base64
import imageio
import IPython
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import PIL.Image
import pyvirtualdisplay
import reverb

import tensorflow as tf

from tf_agents.agents.dqn import dqn_agent
from tf_agents.drivers import py_driver
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.eval import metric_utils
from tf_agents.metrics import tf_metrics
from tf_agents.networks import sequential
from tf_agents.policies import py_tf_eager_policy
from tf_agents.policies import random_tf_policy
from tf_agents.replay_buffers import reverb_replay_buffer
from tf_agents.replay_buffers import reverb_utils
from tf_agents.trajectories import trajectory
from tf_agents.specs import tensor_spec
from tf_agents.utils import common
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /workspaces/gym-dl/dqn.ipynb Cell 2 in <cell line: 11>()
#       <a href='vscode-notebook-cell://codespaces%2Bsamsambutdifferent-gym-dl-54vrr6pwgx27wpw/workspaces/gym-dl/dqn.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> import PIL.Image
#      <a href='vscode-notebook-cell://codespaces%2Bsamsambutdifferent-gym-dl-54vrr6pwgx27wpw/workspaces/gym-dl/dqn.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> import pyvirtualdisplay
# ---> <a href='vscode-notebook-cell://codespaces%2Bsamsambutdifferent-gym-dl-54vrr6pwgx27wpw/workspaces/gym-dl/dqn.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> import reverb
#      <a href='vscode-notebook-cell://codespaces%2Bsamsambutdifferent-gym-dl-54vrr6pwgx27wpw/workspaces/gym-dl/dqn.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> import tensorflow as tf
#      <a href='vscode-notebook-cell://codespaces%2Bsamsambutdifferent-gym-dl-54vrr6pwgx27wpw/workspaces/gym-dl/dqn.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> from tf_agents.agents.dqn import dqn_agent
#
# File /opt/python/latest/lib/python3.10/site-packages/reverb/__init__.py:27, in <module>
#      24 del ensure_tf_install
#      25 # pylint: enable=g-bad-import-order
# ---> 27 from reverb import item_selectors as selectors
#      28 from reverb import rate_limiters
#      30 from reverb import structured_writer as structured
#
# File /opt/python/latest/lib/python3.10/site-packages/reverb/item_selectors.py:19, in <module>
#      15 """Sampling and removing selection strategies."""
#      17 import functools
# ---> 19 from reverb import pybind
#      21 Fifo = pybind.FifoSelector
#      22 Lifo = pybind.LifoSelector
#
# File /opt/python/latest/lib/python3.10/site-packages/reverb/pybind.py:6, in <module>
#       4   from .libpybind import *
#       5 except ImportError as e:
# ----> 6   _load_op_library.reraise_wrapped_error(e)
#       7 del _tf
#
# File /opt/python/latest/lib/python3.10/site-packages/reverb/platform/default/load_op_library.py:47, in reraise_wrapped_error(error)
#      42 if 'undefined symbol' in str(error).lower():
#      43   six.reraise(ImportError,
#      44               ImportError('%s\nOrignal error:\n%s' % (
#      45                   UNDEFINED_SYMBOL_ERROR_MESSAGE, error)),
#      46               sys.exc_info()[2])
# ---> 47 raise error
#
# File /opt/python/latest/lib/python3.10/site-packages/reverb/pybind.py:4, in <module>
#       2 from reverb.platform.default import load_op_library as _load_op_library
#       3 try:
# ----> 4   from .libpybind import *
#       5 except ImportError as e:
#       6   _load_op_library.reraise_wrapped_error(e)
#
# ImportError: libpython3.10.so.1.0: cannot open shared object file: No such file or directory

# %%
# Set up a virtual display for rendering OpenAI gym environments.
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()

# %%
tf.version.VERSION

# %%
num_iterations = 20000 # @param {type:"integer"}

initial_collect_steps = 100  # @param {type:"integer"}
collect_steps_per_iteration =   1# @param {type:"integer"}
replay_buffer_max_length = 100000  # @param {type:"integer"}

batch_size = 64  # @param {type:"integer"}
learning_rate = 1e-3  # @param {type:"number"}
log_interval = 200  # @param {type:"integer"}

num_eval_episodes = 10  # @param {type:"integer"}
eval_interval = 1000  # @param {type:"integer"}
